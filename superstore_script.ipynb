# %%
# importing libraries and data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
superstore = pd.read_csv(r"C:\Users\alexa\OneDrive\Desktop\global super store\Global_Superstore2.csv", encoding='latin-1')

# %%
pd.set_option('display.max_columns', None)

# %%
superstore.head(5)
# Out:
#    Row ID         Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891  31-07-2012  31-07-2012      Same Day    RH-19495
# 1   26341    IN-2013-77878  05-02-2013  07-02-2013  Second Class    JR-16210
# 2   25330    IN-2013-71249  17-10-2013  18-10-2013   First Class    CR-12730
# 3   13524  ES-2013-1579342  28-01-2013  30-01-2013   First Class    KM-16375
# 4   47221     SG-2013-4320  05-11-2013  06-11-2013      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  \
# 0       Rick Hansen     Consumer  New York City         New York
# 1     Justin Ritter    Corporate     Wollongong  New South Wales
# 2      Craig Reiter     Consumer       Brisbane       Queensland
# 3  Katherine Murray  Home Office         Berlin           Berlin
# 4       Rick Hansen     Consumer          Dakar            Dakar
#
#          Country  Postal Code  Market   Region        Product ID    Category  \
# ...

# %% [markdown]
# Cleaning Data and Formating

# %%
superstore['Order Date'] = pd.to_datetime(superstore['Order Date'], infer_datetime_format=True).dt.strftime('%m/%d/%Y')
superstore['Ship Date'] = pd.to_datetime(superstore['Ship Date'], infer_datetime_format=True).dt.strftime('%m/%d/%Y')

# %%
superstore.head(50)
# Out:
#     Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 0    32298   CA-2012-124891  07/31/2012  07/31/2012        Same Day
# 1    26341    IN-2013-77878  05/02/2013  02/07/2013    Second Class
# 2    25330    IN-2013-71249  10/17/2013  10/18/2013     First Class
# 3    13524  ES-2013-1579342  01/28/2013  01/30/2013     First Class
# 4    47221     SG-2013-4320  05/11/2013  11/06/2013        Same Day
# 5    22732    IN-2013-42360  06/28/2013  07/01/2013    Second Class
# 6    30570    IN-2011-81826  07/11/2011  11/09/2011     First Class
# 7    31192    IN-2012-86369  04/14/2012  04/18/2012  Standard Class
# 8    40155   CA-2014-135909  10/14/2014  10/21/2014  Standard Class
# 9    40936   CA-2012-116638  01/28/2012  01/31/2012    Second Class
# 10   34577   CA-2011-102988  05/04/2011  04/09/2011    Second Class
# 11   28879    ID-2012-28402  04/19/2012  04/22/2012     First Class
# 12   45794     SA-2011-1830  12/27/2011  12/29/2011    Second Class
# ...

# %%
superstore.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# City              0
# State             0
# Country           0
# Market            0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# Shipping Cost     0
# Order Priority    0
# dtype: int64

# %%
superstore.drop('Postal Code', axis=1, inplace=True)
